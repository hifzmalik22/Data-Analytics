# %%
#list list are used to stored multiple values in a single item
list are one of 4 built in data types in python .  used to store collection of data 


this_list = [3,6,5,7] # syntax listname = [1,2,3,4]
print(this_list)

# %%
this_list = [3,6,5,7]
print(this_list)
# Out:
# [3, 6, 5, 7]

# %%
type(this_list)
# Out:
# list

# %%
"""list item 
list items are ordered changable and allow duplicates
list items are indexed the first has index [0]

ordered

when we say list are ordered it means the items have a defined order and that order will not change
if you add new items to a list the new item will be placed at the end

changable 
the list is changable meaning that we can change add remove items in a list after it has been created

allow duplication 
sincne lists are indexed list can have items with the same value

this_list = [2,3,4,5,6,2]

list length

to determine how many items are in the list, use len()

data type
lists item can be of any data type
list1 = ["aryan","ankur"]
list2 = [2,5,6]
list3 = [True , False]

type()
mylist = [4,6,7,8]
print(type(mylist))


list consturctor
list(())
 list3 = list(("aryan","ankur")) # note the double round - bracket
"""

# %%
this_list = [2,3,4,5,6,2]
print(this_list)
print(len(this_list))
print(type(this_list))

list3 = list((2,4,5,6,7))
print(list3)
# Out:
# [2, 3, 4, 5, 6, 2]
# 6
# <class 'list'>
# [2, 4, 5, 6, 7]

# %%
"""
access item 
list are indexed and you can access the item by refferening index number

list3[0]

negative indexing 
means strt from the end

range of index 
you can specify a range of indexed by specifyinh where to start and whre to end the range
"""

# %%
print(this_list[0])
# Out:
# 2

# %%
print(this_list[-2])
# Out:
# 6

# %%
cars  = ["honda","maruti","suzuki","tata","toyota","MG","Kia"] # 
print(cars[2:4])
# Out:
# ['suzuki', 'tata']

# %%
#negativbe range indexing 
print(cars[-4:-1])
print(cars[-1:-4]) # it will not show any result
# Out:
# ['tata', 'toyota', 'MG']
# []

# %%
if "byd" in cars:
    print("yes it is avalable")
else: 
    print("it is not avilable")
# Out:
# it is not avilable

# %%
car = input("enter car name to serach:")
if car in cars :
    print("avaiable")
else:
    print("not available")
# Out:
# enter car name to serach: kia
# not available

# %%
#change item value
#to chnage the specific value refer to index number
cars[0] = "byd"

# %%
cars
# Out:
# ['byd', 'maruti', 'suzuki', 'tata', 'toyota', 'MG', 'Kia']

# %%
cars[0:1] = ["honda","byd"]
cars
# Out:
# ['honda', 'byd', 'maruti', 'suzuki', 'tata', 'toyota', 'MG', 'Kia']

# %%
"""
insert item
listname.insert(index number, "value")
"""

cars.insert(2,"citron")
cars
# Out:
# ['honda', 'byd', 'citron', 'maruti', 'suzuki', 'tata', 'toyota', 'MG', 'Kia']

# %%
#append item 
#to add an item to the end of the list use append()

# %%
cars.append("wolkvagon")
cars
# Out:
# ['honda',
#  'byd',
#  'citron',
#  'maruti',
#  'suzuki',
#  'tata',
#  'toyota',
#  'MG',
#  'Kia',
#  'wolkvagon',
#  'wolkvagon']

# %%
"""
extend list 
extend()
"""

# %%
cars.extend(this_list)
cars
# Out:
# ['honda',
#  'byd',
#  'citron',
#  'maruti',
#  'suzuki',
#  'tata',
#  'toyota',
#  'MG',
#  'Kia',
#  'wolkvagon',
#  2,
#  3,
#  4,
#  5,
#  6,
#  2]

# %%
#remove()
cars.remove(6)  # to remove specific item use remove()
cars
# Out:
# ['honda',
#  'byd',
#  'citron',
#  'maruti',
#  'suzuki',
#  'tata',
#  'toyota',
#  'MG',
#  'Kia',
#  'wolkvagon',
#  2,
#  3,
#  4,
#  5,
#  2]

# %%
#pop()  to remove by index number
cars.pop(8)
# Out:
# 'Kia'

# %%
del cars[8]  #del keywords
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 del cars[8]
#
# IndexError: list assignment index out of range

# %%
cars
# Out:
# []

# %%
#clear list to clear all data of list : clear()

cars.clear()

# %%
cars
# Out:
# []

# %%
"""
remove specific index

the pop() method removes the specified index
the del keyword also remove the specified index
"""

# %%
cars
# Out:
# ['honda', 'maruti', 'suzuki', 'tata', 'toyota', 'MG', 'Kia']

# %%
cars.pop(1)
cars
# Out:
# ['honda', 'suzuki', 'tata', 'toyota', 'MG', 'Kia']

# %%
del cars[0]

# %%
cars
# Out:
# ['suzuki', 'tata', 'toyota', 'MG', 'Kia']

# %%
#del keyword can also be used to delte the list completly

del cars

# %%
cars
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 cars
#
# NameError: name 'cars' is not defined

# %%
#sort list alpha
list objects have a sort() method that will sort the list automatically ascending by default

# %%
cars.sort()
cars
# Out:
# ['Kia', 'MG', 'honda', 'maruti', 'suzuki', 'tata', 'toyota']

# %%
new_list = [100,80,90,50,30]
new_list.sort()
new_list
# Out:
# [30, 50, 80, 90, 100]

# %%
#sort descending
# to sort descending use the keyword argument reverse = true

new_list.sort(reverse = True)
new_list
# Out:
# [100, 90, 80, 50, 30]

# %%
#case insensetive sort

cars.sort(key = str.lower)
cars
# Out:
# ['honda', 'Kia', 'maruti', 'MG', 'suzuki', 'tata', 'toyota']

# %%
#reverse order
# the reverse() method is used to show oppsite

cars.reverse()
cars
# Out:
# ['toyota', 'tata', 'suzuki', 'MG', 'maruti', 'Kia', 'honda']

# %%
#copy list in to another
#you can copy list in to another list by using default method copy()
# the list() is a built in method to copy list into another list 
#you can also make copy of a list using the : (slice) operator
cars2 = cars.copy()
cars2
# Out:
# ['toyota', 'tata', 'suzuki', 'MG', 'maruti', 'Kia', 'honda']

# %%
cars3 = list(cars2)
cars3
# Out:
# ['toyota', 'tata', 'suzuki', 'MG', 'maruti', 'Kia', 'honda']

# %%
cars4 = cars[:]
cars4
# Out:
# ['toyota', 'tata', 'suzuki', 'MG', 'maruti', 'Kia', 'honda']

# %%
cars5 = cars + cars2
cars5
# Out:
# ['toyota',
#  'tata',
#  'suzuki',
#  'MG',
#  'maruti',
#  'Kia',
#  'honda',
#  'toyota',
#  'tata',
#  'suzuki',
#  'MG',
#  'maruti',
#  'Kia',
#  'honda']

# %%
#extend()

cars4.extend(cars)
cars4
# Out:
# ['toyota',
#  'tata',
#  'suzuki',
#  'MG',
#  'maruti',
#  'Kia',
#  'honda',
#  'toyota',
#  'tata',
#  'suzuki',
#  'MG',
#  'maruti',
#  'Kia',
#  'honda']

# %%
fruits = list(("apple","cherry","banana"))
fruits
# Out:
# ['apple', 'cherry', 'banana']

# %%
Cities = ["Delhi", "Meerut", "Bareilly", "Khatima", "Jaipur"]
