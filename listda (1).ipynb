# %%
gift = ["Toy","deo","toy","pen","copy","pen"] #  how to create list
gift[0] # access item console
print(gift)
# Out:
# ['Toy', 'deo', 'toy', 'pen', 'copy', 'pen']

# %%
gift[-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 gift[-1]
#
# NameError: name 'gift' is not defined

# %%
print(gift[1:3]) # slicing
print(gift[-1]) # negative indexing
print(gift[-3:-1])# negative slicing
# Out:
# ['perfume', 'pen']
# perfume
# ['pen', 'copy']

# %%
gift[1] = "perfume" #change item value
gift
# Out:
# ['toy', 'perfume', 'pen', 'copy', 'pen']

# %%
gift[1:]
# Out:
# ['perfume', 'pen', 'copy', 'pen']

# %%
gift[:4]
# Out:
# ['toy', 'perfume', 'pen', 'copy']

# %%
if "mobile" in gift:
    print("avilable")
else:
    print("not avilable")
# Out:
# not avilable

# %%
gift[3:4] = ["teddy","colors"] # replace range of items value

# %%
print(gift)
# Out:
# ['toy', 'perfume', 'pen', 'teddy', 'colors', 'pen']

# %%
gift[4:6] = ["cycle"]

# %%
gift
# Out:
# ['toy', 'perfume', 'pen', 'teddy', 'cycle']

# %%
gift[3:5] = "color"

# %%
gift
# Out:
# ['toy', 'perfume', 'pen', 'c', 'o', 'l', 'o', 'r']

# %%
gift.insert(2,"teddy")#insert index no, value

# %%
gift
# Out:
# ['toy', 'perfume', 'teddy', 'pen', 'c', 'o', 'l', 'o', 'r']

# %%
gift.append("creyon")# append item at the last

# %%
gift
# Out:
# ['toy', 'perfume', 'teddy', 'pen', 'c', 'o', 'l', 'o', 'r', 'creyon']

# %%
a = ["a","b"] # list a
b = ["c","d"] # list b
a.extend(b) # a + b
print(a)
# Out:
# ['a', 'b', 'c', 'd']

# %%
a.remove("b")# remove (value)

# %%
a
# Out:
# ['a', 'c', 'd']

# %%
a.pop(0)# pop will remove  entery by index no
# Out:
# 'a'

# %%
a
# Out:
# ['c', 'd']

# %%
del a[0] # del keyword del list name[index no]
print(a)
# Out:
# ['d']

# %%
del a # this will delte your list

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
a = ["a","b"]

# %%
a
# Out:
# ['a', 'b']

# %%
a.clear()# clear the selected list

# %%
a
# Out:
# []

# %%
for x in gift :
    print(x)
# Out:
# toy
# perfume
# teddy
# pen
# c
# o
# l
# o
# r
# creyon

# %%
len(gift)
# Out:
# 10

# %%
for i in range(len(gift)):
    print(gift[i])
# Out:
# toy
# perfume
# teddy
# pen
# c
# o
# l
# o
# r
# creyon

# %%
gift.sort() #sensetive
gift
# Out:
# ['Toy', 'copy', 'deo', 'pen', 'pen', 'toy']

# %%
gift.sort(reverse = True)

# %%
gift
# Out:
# ['toy', 'teddy', 'r', 'perfume', 'pen', 'o', 'o', 'l', 'creyon', 'c']

# %%
gift.sort(key = str.lower) # case insensetive

# %%
gift
# Out:
# ['copy', 'deo', 'pen', 'pen', 'Toy', 'toy']

# %%
gift.reverse()

# %%
gift
# Out:
# ['toy', 'Toy', 'pen', 'pen', 'deo', 'copy']

# %%
cartoon = gift.copy() # shallow copy

# %%
cartoon
# Out:
# ['toy', 'Toy', 'pen', 'pen', 'deo', 'copy']

# %%
My_list = gift[1:4]

# %%
My_list
# Out:
# ['Toy', 'pen', 'pen']

# %%
print(My_list + cartoon)
# Out:
# ['Toy', 'pen', 'pen', 'toy', 'Toy', 'pen', 'pen', 'deo', 'copy']
