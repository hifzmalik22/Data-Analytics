# %%
import pandas as pd
df = pd.read_csv ("wrong_sales_data.csv")
df
# Out:
#    Order_ID Product Quantity   Price Total_Sales Customer_Name  Order_Date  \
# 0   ORD1000     ???        5     NaN       error           NaN  2024-01-01
# 1   ORD1001  Laptop        1     NaN        -500          John  wrong_date
# 2   ORD1002     NaN        2  -200.0        1000          Amit         NaN
# 3   ORD1003     NaN        2     NaN         NaN          John  2024-01-01
# 4   ORD1004     NaN        2   500.0        -500           NaN  2024-01-01
# 5   ORD1005   Phone        1     NaN        -500          John  2023/12/12
# 6   ORD1006     NaN       -3     NaN        1000          Amit  wrong_date
# 7   ORD1007  Tablet      NaN  1000.0        2000          Amit  2023/12/12
# 8   ORD1008     ???        5  -200.0        1000          Amit  2024-01-01
# 9   ORD1009  Laptop        5     NaN        -500          John         NaN
# 10  ORD1010  Laptop       -3     NaN        -500           NaN  wrong_date
# ...

# %%
df=pd.read_csv ("wrong_sales_data.csv")
new_df = df.dropna()
new_df
# Out:
#    Order_ID Product Quantity   Price Total_Sales Customer_Name  Order_Date  \
# 23  ORD1023  Laptop       -3  1000.0        2000          John  wrong_date
#
#    Region
# 23  North

# %%
df.loc[0,'Total_Sales'] = 0
df
# Out:
#    Order_ID Product Quantity   Price Total_Sales Customer_Name  Order_Date  \
# 0   ORD1000     ???        5     NaN           0           NaN  2024-01-01
# 1   ORD1001  Laptop        1     NaN        -500          John  wrong_date
# 2   ORD1002     NaN        2  -200.0        1000          Amit         NaN
# 3   ORD1003     NaN        2     NaN         NaN          John  2024-01-01
# 4   ORD1004     NaN        2   500.0        -500           NaN  2024-01-01
# 5   ORD1005   Phone        1     NaN        -500          John  2023/12/12
# 6   ORD1006     NaN       -3     NaN        1000          Amit  wrong_date
# 7   ORD1007  Tablet      NaN  1000.0        2000          Amit  2023/12/12
# 8   ORD1008     ???        5  -200.0        1000          Amit  2024-01-01
# 9   ORD1009  Laptop        5     NaN        -500          John         NaN
# 10  ORD1010  Laptop       -3     NaN        -500           NaN  wrong_date
# ...

# %%
df.fillna(0, inplace=True)
df
# Out:
#    Order_ID Product Quantity   Price Total_Sales Customer_Name  Order_Date  \
# 0   ORD1000     ???        5     0.0           0             0  2024-01-01
# 1   ORD1001  Laptop        1     0.0        -500          John  wrong_date
# 2   ORD1002       0        2  -200.0        1000          Amit           0
# 3   ORD1003       0        2     0.0           0          John  2024-01-01
# 4   ORD1004       0        2   500.0        -500             0  2024-01-01
# 5   ORD1005   Phone        1     0.0        -500          John  2023/12/12
# 6   ORD1006       0       -3     0.0        1000          Amit  wrong_date
# 7   ORD1007  Tablet        0  1000.0        2000          Amit  2023/12/12
# 8   ORD1008     ???        5  -200.0        1000          Amit  2024-01-01
# 9   ORD1009  Laptop        5     0.0        -500          John           0
# 10  ORD1010  Laptop       -3     0.0        -500             0  wrong_date
# ...

# %%
df["Total_Sales"].fillna(0)
df
# Out:
#    Order_ID Product Quantity   Price Total_Sales Customer_Name  Order_Date  \
# 0   ORD1000     ???        5     0.0           0             0  2024-01-01
# 1   ORD1001  Laptop        1     0.0        -500          John  wrong_date
# 2   ORD1002       0        2  -200.0        1000          Amit           0
# 3   ORD1003       0        2     0.0           0          John  2024-01-01
# 4   ORD1004       0        2   500.0        -500             0  2024-01-01
# 5   ORD1005   Phone        1     0.0        -500          John  2023/12/12
# 6   ORD1006       0       -3     0.0        1000          Amit  wrong_date
# 7   ORD1007  Tablet        0  1000.0        2000          Amit  2023/12/12
# 8   ORD1008     ???        5  -200.0        1000          Amit  2024-01-01
# 9   ORD1009  Laptop        5     0.0        -500          John           0
# 10  ORD1010  Laptop       -3     0.0        -500             0  wrong_date
# ...

# %%
df["Total_Sales"] = df["Total_Sales"].replace("error", 0)
df
# Out:
#    Order_ID Product Quantity   Price Total_Sales Customer_Name  Order_Date  \
# 0   ORD1000     ???        5     0.0           0             0  2024-01-01
# 1   ORD1001  Laptop        1     0.0        -500          John  wrong_date
# 2   ORD1002       0        2  -200.0        1000          Amit           0
# 3   ORD1003       0        2     0.0           0          John  2024-01-01
# 4   ORD1004       0        2   500.0        -500             0  2024-01-01
# 5   ORD1005   Phone        1     0.0        -500          John  2023/12/12
# 6   ORD1006       0       -3     0.0        1000          Amit  wrong_date
# 7   ORD1007  Tablet        0  1000.0        2000          Amit  2023/12/12
# 8   ORD1008     ???        5  -200.0        1000          Amit  2024-01-01
# 9   ORD1009  Laptop        5     0.0        -500          John           0
# 10  ORD1010  Laptop       -3     0.0        -500             0  wrong_date
# ...

# %%
x = df["Total_Sales"].mode()[0]
df.fillna({"Total_Sales": x}, inplace=True)
df
# Out:
# C:\Users\hifzm\AppData\Local\Temp\ipykernel_9716\3050059730.py:1: UserWarning: Unable to sort modes: '<' not supported between instances of 'str' and 'int'
#   x = df["Total_Sales"].mode()[0]
#    Order_ID Product Quantity   Price Total_Sales Customer_Name  Order_Date  \
# 0   ORD1000     ???        5     0.0           0             0  2024-01-01
# 1   ORD1001  Laptop        1     0.0        -500          John  wrong_date
# 2   ORD1002       0        2  -200.0        1000          Amit           0
# 3   ORD1003       0        2     0.0           0          John  2024-01-01
# 4   ORD1004       0        2   500.0        -500             0  2024-01-01
# 5   ORD1005   Phone        1     0.0        -500          John  2023/12/12
# 6   ORD1006       0       -3     0.0        1000          Amit  wrong_date
# 7   ORD1007  Tablet        0  1000.0        2000          Amit  2023/12/12
# 8   ORD1008     ???        5  -200.0        1000          Amit  2024-01-01
# ...

# %%
df = pd.read_csv ("data_cleaning_practice.csv")
print (df.to_string())
# Out:
#      Order_ID Customer_Name     City  Sales  Profit  Quantity  Order_Date
# 0        1001           NaN      NaN  error    20.0       4.0  2023-05-21
# 1        1002         Priya  Lucknow    500    10.0       5.0  2023-04-28
# 2        1003         Karan   Kanpur    100    50.0       5.0  2023-10-04
# 3        1004           NaN   Jaipur    200    30.0       5.0  2023-08-02
# 4        1005          Sana    Delhi    400    50.0       3.0  2023-08-08
# 5        1006         Karan   Jaipur    100    30.0       4.0  2023-01-26
# 6        1007         Karan   Kanpur    100    40.0       NaN  2023-01-09
# 7        1008           NaN   Kanpur    300    50.0       3.0  2023-09-28
# 8        1009         Rohit   Kanpur    500    40.0       1.0  2023-01-10
# 9        1010          Sana   Jaipur    400    20.0       5.0  2023-05-01
# 10       1011           NaN   Kanpur  error    20.0       3.0  2023-05-05
# 11       1012          Sana      NaN  error    10.0       3.0  2023-06-19
# ...

# %%
print (df.duplicated())
print (df.to_string())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool
#      Order_ID Customer_Name     City  Sales  Profit  Quantity  Order_Date
# 0        1001           NaN      NaN  error    20.0       4.0  2023-05-21
# 1        1002         Priya  Lucknow    500    10.0       5.0  2023-04-28
# 2        1003         Karan   Kanpur    100    50.0       5.0  2023-10-04
# 3        1004           NaN   Jaipur    200    30.0       5.0  2023-08-02
# 4        1005          Sana    Delhi    400    50.0       3.0  2023-08-08
# 5        1006         Karan   Jaipur    100    30.0       4.0  2023-01-26
# 6        1007         Karan   Kanpur    100    40.0       NaN  2023-01-09
# 7        1008           NaN   Kanpur    300    50.0       3.0  2023-09-28
# 8        1009         Rohit   Kanpur    500    40.0       1.0  2023-01-10
# ...

# %%
df.drop_duplicates()
# Out:
#      Order_ID Customer_Name     City  Sales  Profit  Quantity  Order_Date
# 0        1001           NaN      NaN  error    20.0       4.0  2023-05-21
# 1        1002         Priya  Lucknow    500    10.0       5.0  2023-04-28
# 2        1003         Karan   Kanpur    100    50.0       5.0  2023-10-04
# 3        1004           NaN   Jaipur    200    30.0       5.0  2023-08-02
# 4        1005          Sana    Delhi    400    50.0       3.0  2023-08-08
# ..        ...           ...      ...    ...     ...       ...         ...
# 495      1496          Neha    Delhi    NaN    30.0       1.0  2023-03-31
# 496      1497          Aman    Delhi  error    30.0       4.0  2023-11-10
# 497      1498         Priya      NaN  error    10.0       5.0  2023-02-23
# 498      1499         Rohit      NaN    200     NaN       2.0  2023-01-12
# 499      1500          Neha  Lucknow  error    40.0       3.0  2023-07-28
#
# [500 rows x 7 columns]

# %%
print (df.to_string())
# Out:
#      Order_ID Customer_Name     City  Sales  Profit  Quantity  Order_Date
# 0        1001           NaN      NaN  error    20.0       4.0  2023-05-21
# 1        1002         Priya  Lucknow    500    10.0       5.0  2023-04-28
# 2        1003         Karan   Kanpur    100    50.0       5.0  2023-10-04
# 3        1004           NaN   Jaipur    200    30.0       5.0  2023-08-02
# 4        1005          Sana    Delhi    400    50.0       3.0  2023-08-08
# 5        1006         Karan   Jaipur    100    30.0       4.0  2023-01-26
# 6        1007         Karan   Kanpur    100    40.0       NaN  2023-01-09
# 7        1008           NaN   Kanpur    300    50.0       3.0  2023-09-28
# 8        1009         Rohit   Kanpur    500    40.0       1.0  2023-01-10
# 9        1010          Sana   Jaipur    400    20.0       5.0  2023-05-01
# 10       1011           NaN   Kanpur  error    20.0       3.0  2023-05-05
# 11       1012          Sana      NaN  error    10.0       3.0  2023-06-19
# ...

# %%
df = pd.read_csv('data_cleaning_practice.csv')

new_df = df.dropna()

print(new_df.to_string())
# Out:
#      Order_ID Customer_Name     City  Sales  Profit  Quantity  Order_Date
# 1        1002         Priya  Lucknow    500    10.0       5.0  2023-04-28
# 2        1003         Karan   Kanpur    100    50.0       5.0  2023-10-04
# 4        1005          Sana    Delhi    400    50.0       3.0  2023-08-08
# 5        1006         Karan   Jaipur    100    30.0       4.0  2023-01-26
# 8        1009         Rohit   Kanpur    500    40.0       1.0  2023-01-10
# 9        1010          Sana   Jaipur    400    20.0       5.0  2023-05-01
# 12       1013          Sana   Jaipur  error    50.0       1.0  2023-03-13
# 16       1017          Neha   Kanpur    400    20.0       2.0  2023-06-03
# 17       1018         Karan   Jaipur  error    30.0       5.0  2023-12-13
# 19       1020         Priya   Kanpur    200    40.0       1.0  2023-03-09
# 20       1021          Neha   Mumbai    500    50.0       1.0  2023-02-19
# 24       1025         Karan  Lucknow    300    10.0       3.0  2023-03-01
# ...

# %%
df = pd.read_csv('data_cleaning_practice.csv')

df.dropna(inplace = True)

print(df.to_string())
# Out:
#      Order_ID Customer_Name     City  Sales  Profit  Quantity  Order_Date
# 1        1002         Priya  Lucknow    500    10.0       5.0  2023-04-28
# 2        1003         Karan   Kanpur    100    50.0       5.0  2023-10-04
# 4        1005          Sana    Delhi    400    50.0       3.0  2023-08-08
# 5        1006         Karan   Jaipur    100    30.0       4.0  2023-01-26
# 8        1009         Rohit   Kanpur    500    40.0       1.0  2023-01-10
# 9        1010          Sana   Jaipur    400    20.0       5.0  2023-05-01
# 12       1013          Sana   Jaipur  error    50.0       1.0  2023-03-13
# 16       1017          Neha   Kanpur    400    20.0       2.0  2023-06-03
# 17       1018         Karan   Jaipur  error    30.0       5.0  2023-12-13
# 19       1020         Priya   Kanpur    200    40.0       1.0  2023-03-09
# 20       1021          Neha   Mumbai    500    50.0       1.0  2023-02-19
# 24       1025         Karan  Lucknow    300    10.0       3.0  2023-03-01
# ...

# %%
df
# Out:
#      Order_ID Customer_Name     City  Sales  Profit  Quantity  Order_Date
# 1        1002         Priya  Lucknow    500    10.0       5.0  2023-04-28
# 2        1003         Karan   Kanpur    100    50.0       5.0  2023-10-04
# 4        1005          Sana    Delhi    400    50.0       3.0  2023-08-08
# 5        1006         Karan   Jaipur    100    30.0       4.0  2023-01-26
# 8        1009         Rohit   Kanpur    500    40.0       1.0  2023-01-10
# ..        ...           ...      ...    ...     ...       ...         ...
# 485      1486          Neha   Mumbai    200    10.0       5.0  2023-12-20
# 490      1491          Neha   Mumbai    400    20.0       4.0  2023-03-07
# 492      1493          Neha  Lucknow    500    40.0       4.0  2023-01-13
# 496      1497          Aman    Delhi  error    30.0       4.0  2023-11-10
# 499      1500          Neha  Lucknow  error    40.0       3.0  2023-07-28
#
# [211 rows x 7 columns]

# %%
df = pd.read_csv('data_cleaning_practice.csv')

df.fillna({"Sales": 1000}, inplace=True)
print (df.to_string())
# Out:
#      Order_ID Customer_Name     City  Sales  Profit  Quantity  Order_Date
# 0        1001           NaN      NaN  error    20.0       4.0  2023-05-21
# 1        1002         Priya  Lucknow    500    10.0       5.0  2023-04-28
# 2        1003         Karan   Kanpur    100    50.0       5.0  2023-10-04
# 3        1004           NaN   Jaipur    200    30.0       5.0  2023-08-02
# 4        1005          Sana    Delhi    400    50.0       3.0  2023-08-08
# 5        1006         Karan   Jaipur    100    30.0       4.0  2023-01-26
# 6        1007         Karan   Kanpur    100    40.0       NaN  2023-01-09
# 7        1008           NaN   Kanpur    300    50.0       3.0  2023-09-28
# 8        1009         Rohit   Kanpur    500    40.0       1.0  2023-01-10
# 9        1010          Sana   Jaipur    400    20.0       5.0  2023-05-01
# 10       1011           NaN   Kanpur  error    20.0       3.0  2023-05-05
# 11       1012          Sana      NaN  error    10.0       3.0  2023-06-19
# ...

# %%
print (df.to_string())
# Out:
#      Order_ID Customer_Name     City  Sales  Profit  Quantity  Order_Date
# 0        1001           NaN      NaN  error    20.0       4.0  2023-05-21
# 1        1002         Priya  Lucknow    500    10.0       5.0  2023-04-28
# 2        1003         Karan   Kanpur    100    50.0       5.0  2023-10-04
# 3        1004           NaN   Jaipur    200    30.0       5.0  2023-08-02
# 4        1005          Sana    Delhi    400    50.0       3.0  2023-08-08
# 5        1006         Karan   Jaipur    100    30.0       4.0  2023-01-26
# 6        1007         Karan   Kanpur    100    40.0       NaN  2023-01-09
# 7        1008           NaN   Kanpur    300    50.0       3.0  2023-09-28
# 8        1009         Rohit   Kanpur    500    40.0       1.0  2023-01-10
# 9        1010          Sana   Jaipur    400    20.0       5.0  2023-05-01
# 10       1011           NaN   Kanpur  error    20.0       3.0  2023-05-05
# 11       1012          Sana      NaN  error    10.0       3.0  2023-06-19
# ...

# %%
x = df ["Profit"].mean()
df.fillna({"Profit":x})
x
print (df.to_string())
# Out:
#      Order_ID Customer_Name     City Sales  Profit  Quantity  Order_Date
# 0        1001           NaN      NaN     0    20.0       4.0  2023-05-21
# 1        1002         Priya  Lucknow   500    10.0       5.0  2023-04-28
# 2        1003         Karan   Kanpur   100    50.0       5.0  2023-10-04
# 3        1004           NaN   Jaipur   200    30.0       5.0  2023-08-02
# 4        1005          Sana    Delhi   400    50.0       3.0  2023-08-08
# 5        1006         Karan   Jaipur   100    30.0       4.0  2023-01-26
# 6        1007         Karan   Kanpur   100    40.0       NaN  2023-01-09
# 7        1008           NaN   Kanpur   300    50.0       3.0  2023-09-28
# 8        1009         Rohit   Kanpur   500    40.0       1.0  2023-01-10
# 9        1010          Sana   Jaipur   400    20.0       5.0  2023-05-01
# 10       1011           NaN   Kanpur     0    20.0       3.0  2023-05-05
# 11       1012          Sana      NaN     0    10.0       3.0  2023-06-19
# ...

# %%
df['Sales'] = df['Sales'].replace('error', 0)
print (df.to_string())
# Out:
#      Order_ID Customer_Name     City Sales  Profit  Quantity  Order_Date
# 0        1001           NaN      NaN     0    20.0       4.0  2023-05-21
# 1        1002         Priya  Lucknow   500    10.0       5.0  2023-04-28
# 2        1003         Karan   Kanpur   100    50.0       5.0  2023-10-04
# 3        1004           NaN   Jaipur   200    30.0       5.0  2023-08-02
# 4        1005          Sana    Delhi   400    50.0       3.0  2023-08-08
# 5        1006         Karan   Jaipur   100    30.0       4.0  2023-01-26
# 6        1007         Karan   Kanpur   100    40.0       NaN  2023-01-09
# 7        1008           NaN   Kanpur   300    50.0       3.0  2023-09-28
# 8        1009         Rohit   Kanpur   500    40.0       1.0  2023-01-10
# 9        1010          Sana   Jaipur   400    20.0       5.0  2023-05-01
# 10       1011           NaN   Kanpur     0    20.0       3.0  2023-05-05
# 11       1012          Sana      NaN     0    10.0       3.0  2023-06-19
# ...

# %%
df.fillna({"Sales": 0})
print (df.to_string())
# Out:
#      Order_ID Customer_Name     City Sales  Profit  Quantity  Order_Date
# 0        1001           NaN      NaN     0    20.0       4.0  2023-05-21
# 1        1002         Priya  Lucknow   500    10.0       5.0  2023-04-28
# 2        1003         Karan   Kanpur   100    50.0       5.0  2023-10-04
# 3        1004           NaN   Jaipur   200    30.0       5.0  2023-08-02
# 4        1005          Sana    Delhi   400    50.0       3.0  2023-08-08
# 5        1006         Karan   Jaipur   100    30.0       4.0  2023-01-26
# 6        1007         Karan   Kanpur   100    40.0       NaN  2023-01-09
# 7        1008           NaN   Kanpur   300    50.0       3.0  2023-09-28
# 8        1009         Rohit   Kanpur   500    40.0       1.0  2023-01-10
# 9        1010          Sana   Jaipur   400    20.0       5.0  2023-05-01
# 10       1011           NaN   Kanpur     0    20.0       3.0  2023-05-05
# 11       1012          Sana      NaN     0    10.0       3.0  2023-06-19
# ...

# %%
x = df["Profit"].mean()

df.fillna({"Profit": x}, inplace=True)
print (df.to_string())
# Out:
#      Order_ID Customer_Name     City Sales     Profit  Quantity  Order_Date
# 0        1001           NaN      NaN     0  20.000000       4.0  2023-05-21
# 1        1002         Priya  Lucknow   500  10.000000       5.0  2023-04-28
# 2        1003         Karan   Kanpur   100  50.000000       5.0  2023-10-04
# 3        1004           NaN   Jaipur   200  30.000000       5.0  2023-08-02
# 4        1005          Sana    Delhi   400  50.000000       3.0  2023-08-08
# 5        1006         Karan   Jaipur   100  30.000000       4.0  2023-01-26
# 6        1007         Karan   Kanpur   100  40.000000       NaN  2023-01-09
# 7        1008           NaN   Kanpur   300  50.000000       3.0  2023-09-28
# 8        1009         Rohit   Kanpur   500  40.000000       1.0  2023-01-10
# 9        1010          Sana   Jaipur   400  20.000000       5.0  2023-05-01
# 10       1011           NaN   Kanpur     0  20.000000       3.0  2023-05-05
# ...

# %%
df['Profit'] = df['Profit'].astype(int)
print (df.to_string())
# Out:
#      Order_ID Customer_Name     City Sales  Profit  Quantity  Order_Date
# 0        1001           NaN      NaN     0      20         4  2023-05-21
# 1        1002         Priya  Lucknow   500      10         5  2023-04-28
# 2        1003         Karan   Kanpur   100      50         5  2023-10-04
# 3        1004           NaN   Jaipur   200      30         5  2023-08-02
# 4        1005          Sana    Delhi   400      50         3  2023-08-08
# 5        1006         Karan   Jaipur   100      30         4  2023-01-26
# 6        1007         Karan   Kanpur   100      40         3  2023-01-09
# 7        1008           NaN   Kanpur   300      50         3  2023-09-28
# 8        1009         Rohit   Kanpur   500      40         1  2023-01-10
# 9        1010          Sana   Jaipur   400      20         5  2023-05-01
# 10       1011           NaN   Kanpur     0      20         3  2023-05-05
# 11       1012          Sana      NaN     0      10         3  2023-06-19
# ...

# %%
x = df["Quantity"].mean()
df.fillna ({"Quantity":x}, inplace = True)
print (df.to_string())
# Out:
#      Order_ID Customer_Name     City Sales  Profit  Quantity  Order_Date
# 0        1001           NaN      NaN     0      20  4.000000  2023-05-21
# 1        1002         Priya  Lucknow   500      10  5.000000  2023-04-28
# 2        1003         Karan   Kanpur   100      50  5.000000  2023-10-04
# 3        1004           NaN   Jaipur   200      30  5.000000  2023-08-02
# 4        1005          Sana    Delhi   400      50  3.000000  2023-08-08
# 5        1006         Karan   Jaipur   100      30  4.000000  2023-01-26
# 6        1007         Karan   Kanpur   100      40  3.021687  2023-01-09
# 7        1008           NaN   Kanpur   300      50  3.000000  2023-09-28
# 8        1009         Rohit   Kanpur   500      40  1.000000  2023-01-10
# 9        1010          Sana   Jaipur   400      20  5.000000  2023-05-01
# 10       1011           NaN   Kanpur     0      20  3.000000  2023-05-05
# 11       1012          Sana      NaN     0      10  3.000000  2023-06-19
# ...

# %%
df["Quantity"] = df ["Quantity"].astype(int)
print (df.to_string())
# Out:
#      Order_ID Customer_Name     City Sales  Profit  Quantity  Order_Date
# 0        1001           NaN      NaN     0      20         4  2023-05-21
# 1        1002         Priya  Lucknow   500      10         5  2023-04-28
# 2        1003         Karan   Kanpur   100      50         5  2023-10-04
# 3        1004           NaN   Jaipur   200      30         5  2023-08-02
# 4        1005          Sana    Delhi   400      50         3  2023-08-08
# 5        1006         Karan   Jaipur   100      30         4  2023-01-26
# 6        1007         Karan   Kanpur   100      40         3  2023-01-09
# 7        1008           NaN   Kanpur   300      50         3  2023-09-28
# 8        1009         Rohit   Kanpur   500      40         1  2023-01-10
# 9        1010          Sana   Jaipur   400      20         5  2023-05-01
# 10       1011           NaN   Kanpur     0      20         3  2023-05-05
# 11       1012          Sana      NaN     0      10         3  2023-06-19
# ...

# %%
x = df["Sales"].median()
df.fillna ({"Sales":x}, inplace = True)
print (df.to_string())
# Out:
#      Order_ID Customer_Name     City  Sales  Profit  Quantity  Order_Date
# 0        1001           NaN      NaN      0      20         4  2023-05-21
# 1        1002         Priya  Lucknow    500      10         5  2023-04-28
# 2        1003         Karan   Kanpur    100      50         5  2023-10-04
# 3        1004           NaN   Jaipur    200      30         5  2023-08-02
# 4        1005          Sana    Delhi    400      50         3  2023-08-08
# 5        1006         Karan   Jaipur    100      30         4  2023-01-26
# 6        1007         Karan   Kanpur    100      40         3  2023-01-09
# 7        1008           NaN   Kanpur    300      50         3  2023-09-28
# 8        1009         Rohit   Kanpur    500      40         1  2023-01-10
# 9        1010          Sana   Jaipur    400      20         5  2023-05-01
# 10       1011           NaN   Kanpur      0      20         3  2023-05-05
# 11       1012          Sana      NaN      0      10         3  2023-06-19
# ...

# %%
x = df["Sales"].median()
df.fillna ({"Sales":x}, inplace = True)
print (df.to_string())
# Out:
#      Order_ID Customer_Name     City  Sales  Profit  Quantity  Order_Date
# 0        1001           NaN      NaN      0      20         4  2023-05-21
# 1        1002         Priya  Lucknow    500      10         5  2023-04-28
# 2        1003         Karan   Kanpur    100      50         5  2023-10-04
# 3        1004           NaN   Jaipur    200      30         5  2023-08-02
# 4        1005          Sana    Delhi    400      50         3  2023-08-08
# 5        1006         Karan   Jaipur    100      30         4  2023-01-26
# 6        1007         Karan   Kanpur    100      40         3  2023-01-09
# 7        1008           NaN   Kanpur    300      50         3  2023-09-28
# 8        1009         Rohit   Kanpur    500      40         1  2023-01-10
# 9        1010          Sana   Jaipur    400      20         5  2023-05-01
# 10       1011           NaN   Kanpur      0      20         3  2023-05-05
# 11       1012          Sana      NaN      0      10         3  2023-06-19
# ...

# %%
df["Sales"] = df ["Sales"].astype(int)
print (df.to_string())
# Out:
#      Order_ID Customer_Name     City  Sales  Profit  Quantity  Order_Date
# 0        1001           NaN      NaN      0      20         4  2023-05-21
# 1        1002         Priya  Lucknow    500      10         5  2023-04-28
# 2        1003         Karan   Kanpur    100      50         5  2023-10-04
# 3        1004           NaN   Jaipur    200      30         5  2023-08-02
# 4        1005          Sana    Delhi    400      50         3  2023-08-08
# 5        1006         Karan   Jaipur    100      30         4  2023-01-26
# 6        1007         Karan   Kanpur    100      40         3  2023-01-09
# 7        1008           NaN   Kanpur    300      50         3  2023-09-28
# 8        1009         Rohit   Kanpur    500      40         1  2023-01-10
# 9        1010          Sana   Jaipur    400      20         5  2023-05-01
# 10       1011           NaN   Kanpur      0      20         3  2023-05-05
# 11       1012          Sana      NaN      0      10         3  2023-06-19
# ...

# %%
import numpy as np

# Step 1: 0 ko NaN me convert karo
df['Sales'] = df['Sales'].replace(0, np.nan)
print (df.to_string())
# Out:
#      Order_ID Customer_Name     City  Sales  Profit  Quantity  Order_Date
# 0        1001           NaN      NaN    NaN      20         4  2023-05-21
# 1        1002         Priya  Lucknow  500.0      10         5  2023-04-28
# 2        1003         Karan   Kanpur  100.0      50         5  2023-10-04
# 3        1004           NaN   Jaipur  200.0      30         5  2023-08-02
# 4        1005          Sana    Delhi  400.0      50         3  2023-08-08
# 5        1006         Karan   Jaipur  100.0      30         4  2023-01-26
# 6        1007         Karan   Kanpur  100.0      40         3  2023-01-09
# 7        1008           NaN   Kanpur  300.0      50         3  2023-09-28
# 8        1009         Rohit   Kanpur  500.0      40         1  2023-01-10
# 9        1010          Sana   Jaipur  400.0      20         5  2023-05-01
# 10       1011           NaN   Kanpur    NaN      20         3  2023-05-05
# 11       1012          Sana      NaN    NaN      10         3  2023-06-19
# ...

# %%
x = df["Sales"].mean()

df.fillna({"Sales": x}, inplace=True)
x
print (df.to_string())
# Out:
#      Order_ID Customer_Name     City       Sales  Profit  Quantity  Order_Date
# 0        1001           NaN      NaN  277.272727      20         4  2023-05-21
# 1        1002         Priya  Lucknow  500.000000      10         5  2023-04-28
# 2        1003         Karan   Kanpur  100.000000      50         5  2023-10-04
# 3        1004           NaN   Jaipur  200.000000      30         5  2023-08-02
# 4        1005          Sana    Delhi  400.000000      50         3  2023-08-08
# 5        1006         Karan   Jaipur  100.000000      30         4  2023-01-26
# 6        1007         Karan   Kanpur  100.000000      40         3  2023-01-09
# 7        1008           NaN   Kanpur  300.000000      50         3  2023-09-28
# 8        1009         Rohit   Kanpur  500.000000      40         1  2023-01-10
# 9        1010          Sana   Jaipur  400.000000      20         5  2023-05-01
# 10       1011           NaN   Kanpur  277.272727      20         3  2023-05-05
# ...

# %%
df['Sales'] = df['Sales'].astype(int)
print (df.to_string())
# Out:
#      Order_ID Customer_Name     City  Sales  Profit  Quantity  Order_Date
# 0        1001           NaN      NaN    277      20         4  2023-05-21
# 1        1002         Priya  Lucknow    500      10         5  2023-04-28
# 2        1003         Karan   Kanpur    100      50         5  2023-10-04
# 3        1004           NaN   Jaipur    200      30         5  2023-08-02
# 4        1005          Sana    Delhi    400      50         3  2023-08-08
# 5        1006         Karan   Jaipur    100      30         4  2023-01-26
# 6        1007         Karan   Kanpur    100      40         3  2023-01-09
# 7        1008           NaN   Kanpur    300      50         3  2023-09-28
# 8        1009         Rohit   Kanpur    500      40         1  2023-01-10
# 9        1010          Sana   Jaipur    400      20         5  2023-05-01
# 10       1011           NaN   Kanpur    277      20         3  2023-05-05
# 11       1012          Sana      NaN    277      10         3  2023-06-19
# ...

# %%
df['Customer_Name'] = df['Customer_Name'].fillna(method='ffill')
print (df.to_string())
# Out:
#      Order_ID Customer_Name     City  Sales  Profit  Quantity  Order_Date
# 0        1001           NaN      NaN    277      20         4  2023-05-21
# 1        1002         Priya  Lucknow    500      10         5  2023-04-28
# 2        1003         Karan   Kanpur    100      50         5  2023-10-04
# 3        1004         Karan   Jaipur    200      30         5  2023-08-02
# 4        1005          Sana    Delhi    400      50         3  2023-08-08
# 5        1006         Karan   Jaipur    100      30         4  2023-01-26
# 6        1007         Karan   Kanpur    100      40         3  2023-01-09
# 7        1008         Karan   Kanpur    300      50         3  2023-09-28
# 8        1009         Rohit   Kanpur    500      40         1  2023-01-10
# 9        1010          Sana   Jaipur    400      20         5  2023-05-01
# 10       1011          Sana   Kanpur    277      20         3  2023-05-05
# 11       1012          Sana      NaN    277      10         3  2023-06-19
# ...

# %%
import matplotlib.pyplot as plt
df.plot()

plt.show()

# %%
df.plot(kind = "hist", x = "Sales", y = "Profit")

plt.show()

# %%
df.plot(kind = "hist")

plt.show()
