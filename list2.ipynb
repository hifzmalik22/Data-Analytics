# %%
students = ["kaif","rakeh","azhar"]
print(students)

print(students[0:2])
print(students[-1])
print(len(students))
print(type(students))
# Out:
# ['kaif', 'rakeh', 'azhar']
# ['kaif', 'rakeh']
# azhar
# 3
# <class 'list'>

# %%
for x in students:
    print(x)
# Out:
# kaif
# rakeh
# azhar

# %%
cars  = ["honda","maruti","suzuki","tata","toyota","MG","Kia","kia","byd"]

# %%
print(cars)
# Out:
# ['honda', 'maruti', 'suzuki', 'tata', 'toyota', 'MG', 'Kia', 'kia']

# %%
car_name = input("enter car name to search: ")

if car_name in cars:
    print("available")
else:
    print("not available")
# Out:
# enter car name to search:  eisher
# not available

# %%
cars.insert(2,"citron")

# %%
cars
# Out:
# ['honda',
#  'maruti',
#  'citron',
#  'suzuki',
#  'tata',
#  'toyota',
#  'MG',
#  'Kia',
#  'kia',
#  'byd']

# %%
cars.append("wolksvagon")

# %%
cars
# Out:
# ['honda',
#  'maruti',
#  'citron',
#  'suzuki',
#  'tata',
#  'toyota',
#  'MG',
#  'Kia',
#  'kia',
#  'byd',
#  'wolksvagon']

# %%
cars2 = ["ashok", "eisher"]
cars.extend(cars2)

# %%
cars
# Out:
# ['honda',
#  'maruti',
#  'citron',
#  'suzuki',
#  'tata',
#  'toyota',
#  'MG',
#  'Kia',
#  'kia',
#  'byd',
#  'wolksvagon',
#  'ashok',
#  'eisher']

# %%
cars.remove("kia") # remove by value

# %%
cars
# Out:
# ['honda',
#  'maruti',
#  'citron',
#  'suzuki',
#  'tata',
#  'toyota',
#  'MG',
#  'Kia',
#  'byd',
#  'wolksvagon',
#  'ashok',
#  'eisher']

# %%
cars.pop(-1)#remove by index no
# Out:
# 'eisher'

# %%
del cars[-1]

# %%
cars
# Out:
# ['honda',
#  'maruti',
#  'citron',
#  'suzuki',
#  'tata',
#  'toyota',
#  'MG',
#  'Kia',
#  'byd',
#  'wolksvagon']

# %%
del cars

# %%
cars
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 cars
#
# NameError: name 'cars' is not defined

# %%
cars.sort()

# %%
cars
# Out:
# ['Kia', 'MG', 'byd', 'honda', 'kia', 'maruti', 'suzuki', 'tata', 'toyota']

# %%
cars.sort(key = str.lower)

# %%
cars
# Out:
# ['byd', 'honda', 'Kia', 'kia', 'maruti', 'MG', 'suzuki', 'tata', 'toyota']

# %%
cars.reverse()

# %%
cars
# Out:
# ['toyota', 'tata', 'suzuki', 'MG', 'maruti', 'kia', 'Kia', 'honda', 'byd']
